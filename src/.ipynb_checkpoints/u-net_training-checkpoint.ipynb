# %% [markdown]
# # plaq-u-net: multi-patch consensus U-Net for automated detection and segmentation of the carotid arteries on black blood MRI sequences

# %% [markdown]
# E. Lavrova, 2022
#
# This is a code supporting the corresponding paper.

# %% [markdown]
# Packages import:

# %%
import os
import numpy as np
from os import listdir
from xml.etree import ElementTree
from numpy import zeros
from numpy import asarray
from numpy import expand_dims
from numpy import mean
import pydicom
import random
import matplotlib.pyplot as plt
import glob
import matplotlib.patches as patches

from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from skimage import morphology
from skimage.filters import threshold_otsu, threshold_local

import cv2

from tqdm import tqdm_notebook, tnrange
from itertools import chain
from sklearn.model_selection import train_test_split

import keras
from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

import random
import pandas as pd

import albumentations as A

import SimpleITK as sitk

plt.style.use("ggplot")
# Out:
# Using TensorFlow backend.
# C:\Users\E.Lavrova\AppData\Roaming\Python\Python37\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# GPU assignment:

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = '0,3'                        
import tensorflow as tf
import keras.backend as K
K.tensorflow_backend._get_available_gpus()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0627 17:57:03.048541 35432 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0627 17:57:03.050541 35432 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0627 17:57:03.052543 35432 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0627 17:57:06.565090 35432 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# ['/job:localhost/replica:0/task:0/device:GPU:0',
#  '/job:localhost/replica:0/task:0/device:GPU:1']

# %% [markdown]
# ## 1. Data load

# %% [markdown]
# Getting image/contour names:

# %%
images = glob.glob('../data/*/T1W_*.dcm')
contours = glob.glob('../data/*/MASSExport/*.dcm')

# %% [markdown]
# Number of image/contour files:

# %%
len(images), len(contours)
# Out:
# (2806, 2821)

# %% [markdown]
# Getting patients with contours presented:

# %%
sub_names_list = []
for image in images:
    sub_name = image.split(os.sep)[1].split('_')[0]
    con_names = glob.glob(os.path.join(os.path.split(image)[0],'MASSExport')+os.sep+'*'+ image.split(os.sep)[2][-10:-4]+'*.dcm')
    if len(con_names)>0:
        sub_names_list.append(sub_name)
        
sub_names = np.unique(sub_names_list)

# %% [markdown]
# Splitting subs into centers:

# %%
sub_names_amc = []
sub_names_mumc = []
sub_names_umcu = []
sub_names_emc = []

for sub_name in sub_names:
    if 'AMC' in sub_name:
        sub_names_amc.append(sub_name)
    if 'MUMC' in sub_name:
        sub_names_mumc.append(sub_name)
    if 'UMCU' in sub_name:
        sub_names_umcu.append(sub_name)
    if 'EMC' in sub_name:
        sub_names_emc.append(sub_name)
        
print (len(sub_names_amc), len(sub_names_mumc), len(sub_names_umcu), len(sub_names_emc))
# Out:
# 13 115 25 34

# %% [markdown]
# Data split for training, validation, and testing stratified per center:

# %%
sub_names_amc_train, sub_names_amc_valid_test = train_test_split(sub_names_amc, test_size=0.3, 
                                                                 random_state=2022, shuffle=True)
sub_names_amc_valid, sub_names_amc_test = train_test_split(sub_names_amc_valid_test, test_size=0.5, 
                                                           random_state=2022, shuffle=True)

sub_names_mumc_train, sub_names_mumc_valid_test = train_test_split(sub_names_mumc, test_size=0.3, 
                                                                 random_state=2022, shuffle=True)
sub_names_mumc_valid, sub_names_mumc_test = train_test_split(sub_names_mumc_valid_test, test_size=0.5, 
                                                           random_state=2022, shuffle=True)

sub_names_umcu_train, sub_names_umcu_valid_test = train_test_split(sub_names_umcu, test_size=0.3, 
                                                                 random_state=2022, shuffle=True)
sub_names_umcu_valid, sub_names_umcu_test = train_test_split(sub_names_umcu_valid_test, test_size=0.5, 
                                                           random_state=2022, shuffle=True)

sub_names_train = sub_names_amc_train + sub_names_mumc_train + sub_names_umcu_train
sub_names_valid = sub_names_amc_valid + sub_names_mumc_valid + sub_names_umcu_valid
sub_names_test = sub_names_amc_test + sub_names_mumc_test + sub_names_umcu_test

print (len(sub_names_amc_train), len(sub_names_mumc_train), len(sub_names_umcu_train))
print (len(sub_names_amc_valid), len(sub_names_mumc_valid), len(sub_names_umcu_valid))
print (len(sub_names_amc_test), len(sub_names_mumc_test), len(sub_names_umcu_test))
print (len(sub_names_emc))
# Out:
# 9 80 17
# 2 17 4
# 2 18 4
# 34

# %% [markdown]
# Number of patients in training, validation, and testing subsets per center:

# %% [markdown]
# |DS | Total  | Train    | Valid   | Test   | Ext test |
# |---:|:-------------|:-----------|:------|:------|:-----|
# | AMC | 13  | 9 | 2   | 2     |0|
# | MUMC | 115  | 80    | 17   | 18     |0|
# | UMCU | 25  | 17    | 4   | 4     |0|
# | EMC | 34|0|0|0|34|
# | Total | 187  | 106    | 23   | 24     |34|

# %% [markdown]
# Getting .dcm files for every subset:

# %%
img_names_train = []
img_names_valid = []
img_names_test = []

for sub_name_train in sub_names_train:
    img_names_train.extend(glob.glob('../data/'+sub_name_train+'*/T1W_*.dcm'))

for sub_name_valid in sub_names_valid:
    img_names_valid.extend(glob.glob('../data/'+sub_name_valid+'*/T1W_*.dcm'))
    
for sub_name_test in sub_names_test:
    img_names_test.extend(glob.glob('../data/'+sub_name_test+'*/T1W_*.dcm'))
    
print (len(img_names_train), len(img_names_valid), len(img_names_test))
# Out:
# 1589 345 360

# %%
img_names_emc = []

for sub_name_emc in sub_names_emc:
    img_names_emc.extend(glob.glob('../data/'+sub_name_emc+'*/T1W_*.dcm'))
    
len(img_names_emc)
# Out:
# 512

# %% [markdown]
# Training data aggregation:

# %%
im_side = 512

# empty arrays for training data

X_train = np.zeros((len(img_names_train), im_side, im_side, 1), dtype = np.uint8)
y_train = np.zeros((len(img_names_train), im_side, im_side, 1), dtype = np.uint8)

X_valid = np.zeros((len(img_names_valid), im_side, im_side, 1), dtype = np.uint8)
y_valid = np.zeros((len(img_names_valid), im_side, im_side, 1), dtype = np.uint8)

X_test = np.zeros((len(img_names_test), im_side, im_side, 1), dtype = np.uint8)
y_test = np.zeros((len(img_names_test), im_side, im_side, 1), dtype = np.uint8)

# %%
# read DICOM from path to array

def path2array(dcm_path):
    arr_dcm = pydicom.read_file(dcm_path, force = True)
    arr_dcm.file_meta.TransferSyntaxUID = pydicom.uid.ImplicitVRLittleEndian
    arr = arr_dcm.pixel_array
    return arr

# %%
# slice normalization and training patch crop

def norm_crop(img_arr, con_arr, im_side, rs):
    
    random.seed(rs)
    
    img_min = np.min(img_arr) 
    img_max = np.max(img_arr) 
    
    img_norm = np.copy((img_arr - img_min)/(img_max - img_min)*255).astype(np.uint8)

    img_norm_crop = np.copy(img_norm[8:-8, 8:-8])
    con_crop = np.copy(con_arr[8:-8, 8:-8])

    return img_norm_crop, con_crop>0

# %%
# image pre-processing: N4 bias field correction

def correctBiasField(img_input):
    
    corrected = False
    img_output = np.zeros(img_input.shape)

    while not corrected:

        try:
            corrector = sitk.N4BiasFieldCorrectionImageFilter()
            inputImage = sitk.GetImageFromArray(img_input)
            inputImage = sitk.Cast(inputImage, sitk.sitkFloat32)
            output = corrector.Execute(inputImage)
            img_output = sitk.GetArrayFromImage(output)
            corrected = True
        except:
            print ('BFC failed')

    return img_output

# %%
# aggregation of the training patches from the corresponding DICOM paths

def paths2dataarray(paths_list, X_array, y_array, im_side):
    
    i = 0

    for impth in paths_list:

        img = path2array(impth)
        con_name = glob.glob(os.path.join(os.path.split(impth)[0],'MASSExport')+os.sep+'*'+ impth.split(os.sep)[2][-10:-4]+'*.dcm')[0]
        con = path2array(con_name)
        
        #img_bfc = correctBiasField(img)
        
        img_min = np.min(img)
        img_max = np.max(img)

        if (np.sum(con)>0)&((img_max - img_min)>0):

            img_prep, con_prep = norm_crop(img, con, im_side, i)

            X_array[i, ..., 0] = img_prep
            y_array[i, ..., 0] = con_prep

            i+=1

# %%
# aggregation of the training, validation, and testing patches

paths2dataarray(img_names_train, X_train, y_train, 512)
paths2dataarray(img_names_valid, X_valid, y_valid, 512)
paths2dataarray(img_names_test, X_test, y_test, 512)

# %%
# visualization of the training patches

for i in range (0, 10):
    plt.imshow(X_train[i, ..., 0], cmap = 'bone')
    plt.imshow(y_train[i, ..., 0], alpha = 0.3)
    plt.axis('Off')
    plt.show()

# %% [markdown]
# ## 2. Data augmentation

# %% [markdown]
# Defining transformations:

# %%
transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.RandomSizedCrop(min_max_height=(384, 512), height=512, width=512, p=0.5),
    A.VerticalFlip(p=0.5),
    A.Blur(p=0.5),
    A.GaussNoise(p=0.5),
    A.RandomBrightnessContrast(brightness_limit=0.25, contrast_limit=0.25, p=0.5),
    A.RandomGamma(p=0.5)
])

# %% [markdown]
# Generation of the augmented patches:

# %%
# n_augms random transformations of the images X and masks y

def augment_ds(X, y, n_augms):
    
    counter = 0
    dim = y[0, ..., 0].shape
    n_samples = y.shape[0]
    
    X_aug = np.zeros((int(n_samples*n_augms), dim[0], dim[1], 1), dtype = np.uint8)
    y_aug = np.zeros((int(n_samples*n_augms), dim[0], dim[1], 1), dtype = np.uint8)
    
    for smpl in range (0, n_samples):
        for augm in range (0, n_augms):
            
            random.seed(counter)
            augmented = transform(image=X[smpl, ..., 0], mask=y[smpl, ..., 0])
            X_aug[counter, ..., 0] = augmented['image']
            y_aug[counter, ..., 0] = augmented['mask']
            counter += 1
            
    return X_aug, y_aug

# %% [markdown]
# Writing augmented data into arrays:

# %%
X_train_aug, y_train_aug = augment_ds(X_train, y_train, 10)
X_valid_aug, y_valid_aug = augment_ds(X_train, y_train, 10)

# %% [markdown]
# Visualization of the transformed images:

# %%
n_sample = 5

plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X_train[n_sample//10, ..., 0])
plt.contour(y_train[n_sample//10, ..., 0], colors='r')
plt.subplot(122)
plt.imshow(X_train_aug[n_sample, ..., 0])
plt.contour(y_train_aug[n_sample, ..., 0], colors='r')
plt.show()

# %% [markdown]
# ## 3. U-Net construction

# %% [markdown]
# Defining blocks:

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)

    return x

def get_unet(input_img, n_filters = 8, dropout = 0.2, batchnorm = True):
    """Function to define the UNET Model"""
    # Contracting Path
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)

    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)

    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)

    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)

    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)

    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)

    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)

    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)

    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %% [markdown]
# Custom scores:

# %%
def dice_coef(y_true, y_pred):
    from keras import backend as K
    smooth=1
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

def dice_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

def custom_loss(y_true, y_pred):
    from keras.losses import binary_crossentropy
    return 0.5*keras.losses.binary_crossentropy(y_true,y_pred)+0.5*dice_loss(y_true,y_pred)

# %% [markdown]
# Model compilation:

# %%
input_img = Input((im_side, im_side, 1), name='img')

model_simple = get_unet(input_img, n_filters=16, dropout=0.05, batchnorm=True)
model_simple.compile(optimizer=Adam(), loss=custom_loss, metrics=['accuracy', dice_coef])
model_simple.summary()

model_aug = get_unet(input_img, n_filters=16, dropout=0.05, batchnorm=True)
model_aug.compile(optimizer=Adam(), loss=custom_loss, metrics=['accuracy', dice_coef])
model_aug.summary()
# Out:
# W0627 18:05:10.453706 35432 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0627 18:05:10.458702 35432 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0627 18:05:10.460705 35432 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# W0627 18:05:10.487706 35432 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0627 18:05:10.538706 35432 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0627 18:05:10.628708 35432 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0627 18:05:10.632845 35432 deprecation.py:506] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0627 18:05:11.438788 35432 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0627 18:05:12.251720 35432 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0627 18:05:12.268183 35432 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0627 18:05:12.277184 35432 deprecation.py:323] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                (None, 512, 512, 1)  0
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 512, 512, 16) 160         img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 512, 512, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 512, 512, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 256, 256, 16) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256, 256, 16) 0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 256, 32) 4640        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 256, 256, 32) 128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 256, 256, 32) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 128, 128, 32) 0           activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128, 128, 32) 0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 128, 64) 18496       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 128, 128, 64) 256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 128, 128, 64) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 64, 64, 64)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64, 64, 64)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 128)  73856       dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 64, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 128)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 128)  0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 256)  295168      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 128)  295040      activation_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 256)  0           conv2d_transpose_1[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64, 64, 256)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 128)  295040      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 64) 73792       activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_2[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 128, 128, 128 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 64) 73792       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 128, 128, 64) 256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 128, 128, 64) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 32) 18464       activation_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 64) 0           conv2d_transpose_3[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 256, 256, 64) 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 32) 18464       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 256, 256, 32) 128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 256, 256, 32) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 512, 512, 16) 4624        activation_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 512, 512, 32) 0           conv2d_transpose_4[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 512, 512, 32) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 512, 512, 16) 4624        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 512, 512, 16) 64          conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 512, 512, 16) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 512, 512, 1)  17          activation_18[0][0]
# ==================================================================================================
# Total params: 1,179,121
# Trainable params: 1,177,649
# Non-trainable params: 1,472
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                (None, 512, 512, 1)  0
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 512, 512, 16) 160         img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 512, 512, 16) 64          conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 512, 512, 16) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 256, 256, 16) 0           activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 256, 256, 16) 0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 256, 256, 32) 4640        dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 256, 256, 32) 128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 256, 256, 32) 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 128, 128, 32) 0           activation_22[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 128, 128, 32) 0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 128, 128, 64) 18496       dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 128, 128, 64) 256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 128, 128, 64) 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 64, 64, 64)   0           activation_24[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 64, 64, 64)   0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 64, 128)  73856       dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 64, 64, 128)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 64, 64, 128)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 32, 32, 128)  0           activation_26[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 32, 32, 128)  0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 256)  295168      dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 32, 32, 256)  1024        conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 32, 32, 256)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 64, 64, 128)  295040      activation_28[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           conv2d_transpose_5[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 64, 64, 256)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 64, 128)  295040      dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 64, 64, 128)  512         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 64, 64, 128)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 128, 128, 64) 73792       activation_30[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_6[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 128, 128, 128 0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 128, 128, 64) 73792       dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 128, 128, 64) 256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 128, 128, 64) 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 32) 18464       activation_32[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 64) 0           conv2d_transpose_7[0][0]
#                                                                  activation_22[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 256, 256, 64) 0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 256, 256, 32) 18464       dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 256, 256, 32) 128         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 256, 256, 32) 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 512, 512, 16) 4624        activation_34[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 512, 512, 32) 0           conv2d_transpose_8[0][0]
#                                                                  activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 512, 512, 32) 0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 512, 512, 16) 4624        dropout_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 512, 512, 16) 64          conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 512, 512, 16) 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 512, 512, 1)  17          activation_36[0][0]
# ==================================================================================================
# Total params: 1,179,121
# Trainable params: 1,177,649
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %% [markdown]
# Callbacks:

# %%
callbacks_simple = [
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1),
    ModelCheckpoint('../res/u-net_simple.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

callbacks_aug = [
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1),
    ModelCheckpoint('../res/u-net_aug.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %% [markdown]
# ## 4. Model training with and without augmentation

# %% [markdown]
# Models training (with and w/o augmentation):

# %%
# simple model (w/o data augmentation)

results_simple = model_simple.fit(X_train, y_train,
                                  batch_size=16, epochs=100, 
                                  callbacks=callbacks_simple, 
                                  validation_data=(X_valid, y_valid))
# Out:
# W0627 15:45:41.574438 18132 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0627 15:45:42.063782 18132 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# W0627 15:45:42.665403 18132 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
# Train on 1589 samples, validate on 345 samples
# Epoch 1/100
# W0627 15:45:44.309714 18132 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# 1589/1589 [==============================] - 48s 30ms/step - loss: 0.6565 - acc: 0.9608 - dice_coef: 0.0061 - val_loss: 0.5913 - val_acc: 0.9944 - val_dice_coef: 0.0072
#
# Epoch 00001: val_loss improved from inf to 0.59133, saving model to ../res/u-net_simple.h5
# Epoch 2/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.5623 - acc: 0.9968 - dice_coef: 0.0086 - val_loss: 0.5458 - val_acc: 0.9967 - val_dice_coef: 0.0103
#
# Epoch 00002: val_loss improved from 0.59133 to 0.54582, saving model to ../res/u-net_simple.h5
# Epoch 3/100
# 1589/1589 [==============================] - 33s 21ms/step - loss: 0.5176 - acc: 0.9924 - dice_coef: 0.0425 - val_loss: 0.5195 - val_acc: 0.9823 - val_dice_coef: 0.0551
#
# Epoch 00003: val_loss improved from 0.54582 to 0.51954, saving model to ../res/u-net_simple.h5
# Epoch 4/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.4604 - acc: 0.9926 - dice_coef: 0.1228 - val_loss: 0.4625 - val_acc: 0.9957 - val_dice_coef: 0.1058
#
# Epoch 00004: val_loss improved from 0.51954 to 0.46252, saving model to ../res/u-net_simple.h5
# Epoch 5/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.3769 - acc: 0.9949 - dice_coef: 0.2698 - val_loss: 0.5380 - val_acc: 0.9451 - val_dice_coef: 0.0616
#
# Epoch 00005: val_loss did not improve from 0.46252
# Epoch 6/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.2931 - acc: 0.9963 - dice_coef: 0.4309 - val_loss: 0.3619 - val_acc: 0.9959 - val_dice_coef: 0.2974
#
# Epoch 00006: val_loss improved from 0.46252 to 0.36185, saving model to ../res/u-net_simple.h5
# Epoch 7/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.2466 - acc: 0.9970 - dice_coef: 0.5216 - val_loss: 0.3262 - val_acc: 0.9960 - val_dice_coef: 0.3694
#
# Epoch 00007: val_loss improved from 0.36185 to 0.32616, saving model to ../res/u-net_simple.h5
# Epoch 8/100
# 1589/1589 [==============================] - 33s 21ms/step - loss: 0.2126 - acc: 0.9974 - dice_coef: 0.5879 - val_loss: 0.3199 - val_acc: 0.9962 - val_dice_coef: 0.3837
#
# Epoch 00008: val_loss improved from 0.32616 to 0.31986, saving model to ../res/u-net_simple.h5
# Epoch 9/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.1874 - acc: 0.9977 - dice_coef: 0.6372 - val_loss: 0.4199 - val_acc: 0.9966 - val_dice_coef: 0.1862
#
# Epoch 00009: val_loss did not improve from 0.31986
# Epoch 10/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.1702 - acc: 0.9980 - dice_coef: 0.6706 - val_loss: 0.3464 - val_acc: 0.9964 - val_dice_coef: 0.3331
#
# Epoch 00010: val_loss did not improve from 0.31986
# Epoch 11/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.1540 - acc: 0.9982 - dice_coef: 0.7018 - val_loss: 0.3292 - val_acc: 0.9965 - val_dice_coef: 0.3678
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00011: val_loss did not improve from 0.31986
# Epoch 12/100
# 1589/1589 [==============================] - 33s 21ms/step - loss: 0.1157 - acc: 0.9987 - dice_coef: 0.7758 - val_loss: 0.3261 - val_acc: 0.9965 - val_dice_coef: 0.3733
#
# Epoch 00012: val_loss did not improve from 0.31986
# Epoch 13/100
# 1589/1589 [==============================] - 33s 21ms/step - loss: 0.1060 - acc: 0.9988 - dice_coef: 0.7947 - val_loss: 0.3465 - val_acc: 0.9965 - val_dice_coef: 0.3327
#
# Epoch 00013: val_loss did not improve from 0.31986
# Epoch 14/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.1006 - acc: 0.9989 - dice_coef: 0.8053 - val_loss: 0.3416 - val_acc: 0.9965 - val_dice_coef: 0.3424
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00014: val_loss did not improve from 0.31986
# Epoch 15/100
# 1589/1589 [==============================] - 33s 21ms/step - loss: 0.0959 - acc: 0.9989 - dice_coef: 0.8142 - val_loss: 0.3389 - val_acc: 0.9965 - val_dice_coef: 0.3481
#
# Epoch 00015: val_loss did not improve from 0.31986
# Epoch 16/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0940 - acc: 0.9990 - dice_coef: 0.8180 - val_loss: 0.3388 - val_acc: 0.9965 - val_dice_coef: 0.3483
#
# Epoch 00016: val_loss did not improve from 0.31986
# Epoch 17/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0937 - acc: 0.9990 - dice_coef: 0.8184 - val_loss: 0.3344 - val_acc: 0.9965 - val_dice_coef: 0.3571
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00017: val_loss did not improve from 0.31986
# Epoch 18/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0939 - acc: 0.9990 - dice_coef: 0.8182 - val_loss: 0.3331 - val_acc: 0.9965 - val_dice_coef: 0.3598
#
# Epoch 00018: val_loss did not improve from 0.31986
# Epoch 19/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0938 - acc: 0.9990 - dice_coef: 0.8184 - val_loss: 0.3366 - val_acc: 0.9965 - val_dice_coef: 0.3527
#
# Epoch 00019: val_loss did not improve from 0.31986
# Epoch 20/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0919 - acc: 0.9990 - dice_coef: 0.8221 - val_loss: 0.3339 - val_acc: 0.9965 - val_dice_coef: 0.3582
#
# Epoch 00020: val_loss did not improve from 0.31986
# Epoch 21/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0921 - acc: 0.9990 - dice_coef: 0.8215 - val_loss: 0.3335 - val_acc: 0.9965 - val_dice_coef: 0.3591
#
# Epoch 00021: val_loss did not improve from 0.31986
# Epoch 22/100
# 1589/1589 [==============================] - 33s 21ms/step - loss: 0.0919 - acc: 0.9990 - dice_coef: 0.8219 - val_loss: 0.3329 - val_acc: 0.9965 - val_dice_coef: 0.3603
#
# Epoch 00022: val_loss did not improve from 0.31986
# Epoch 23/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0932 - acc: 0.9990 - dice_coef: 0.8195 - val_loss: 0.3374 - val_acc: 0.9966 - val_dice_coef: 0.3512
#
# Epoch 00023: val_loss did not improve from 0.31986
# Epoch 24/100
# 1589/1589 [==============================] - 33s 21ms/step - loss: 0.0917 - acc: 0.9990 - dice_coef: 0.8224 - val_loss: 0.3341 - val_acc: 0.9966 - val_dice_coef: 0.3579
#
# Epoch 00024: val_loss did not improve from 0.31986
# Epoch 25/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0910 - acc: 0.9990 - dice_coef: 0.8239 - val_loss: 0.3348 - val_acc: 0.9966 - val_dice_coef: 0.3565
#
# Epoch 00025: val_loss did not improve from 0.31986
# Epoch 26/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0910 - acc: 0.9990 - dice_coef: 0.8238 - val_loss: 0.3372 - val_acc: 0.9966 - val_dice_coef: 0.3517
#
# Epoch 00026: val_loss did not improve from 0.31986
# Epoch 27/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0889 - acc: 0.9990 - dice_coef: 0.8278 - val_loss: 0.3366 - val_acc: 0.9966 - val_dice_coef: 0.3530
#
# Epoch 00027: val_loss did not improve from 0.31986
# Epoch 28/100
# 1589/1589 [==============================] - 33s 21ms/step - loss: 0.0892 - acc: 0.9990 - dice_coef: 0.8272 - val_loss: 0.3368 - val_acc: 0.9966 - val_dice_coef: 0.3526
#
# Epoch 00028: val_loss did not improve from 0.31986
# Epoch 29/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0894 - acc: 0.9990 - dice_coef: 0.8268 - val_loss: 0.3334 - val_acc: 0.9965 - val_dice_coef: 0.3596
#
# Epoch 00029: val_loss did not improve from 0.31986
# Epoch 30/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0886 - acc: 0.9990 - dice_coef: 0.8285 - val_loss: 0.3362 - val_acc: 0.9965 - val_dice_coef: 0.3540
#
# Epoch 00030: val_loss did not improve from 0.31986
# Epoch 31/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0892 - acc: 0.9990 - dice_coef: 0.8273 - val_loss: 0.3340 - val_acc: 0.9965 - val_dice_coef: 0.3585
#
# Epoch 00031: val_loss did not improve from 0.31986
# Epoch 32/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0878 - acc: 0.9990 - dice_coef: 0.8300 - val_loss: 0.3324 - val_acc: 0.9965 - val_dice_coef: 0.3618
#
# Epoch 00032: val_loss did not improve from 0.31986
# Epoch 33/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0880 - acc: 0.9990 - dice_coef: 0.8296 - val_loss: 0.3355 - val_acc: 0.9966 - val_dice_coef: 0.3554
#
# Epoch 00033: val_loss did not improve from 0.31986
# Epoch 34/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0876 - acc: 0.9990 - dice_coef: 0.8304 - val_loss: 0.3336 - val_acc: 0.9965 - val_dice_coef: 0.3592
#
# Epoch 00034: val_loss did not improve from 0.31986
# Epoch 35/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0892 - acc: 0.9990 - dice_coef: 0.8273 - val_loss: 0.3356 - val_acc: 0.9966 - val_dice_coef: 0.3554
#
# Epoch 00035: val_loss did not improve from 0.31986
# Epoch 36/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0869 - acc: 0.9990 - dice_coef: 0.8317 - val_loss: 0.3313 - val_acc: 0.9965 - val_dice_coef: 0.3640
#
# Epoch 00036: val_loss did not improve from 0.31986
# Epoch 37/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0883 - acc: 0.9990 - dice_coef: 0.8291 - val_loss: 0.3340 - val_acc: 0.9965 - val_dice_coef: 0.3588
#
# Epoch 00037: val_loss did not improve from 0.31986
# Epoch 38/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0864 - acc: 0.9990 - dice_coef: 0.8327 - val_loss: 0.3356 - val_acc: 0.9965 - val_dice_coef: 0.3555
#
# Epoch 00038: val_loss did not improve from 0.31986
# Epoch 39/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0857 - acc: 0.9991 - dice_coef: 0.8341 - val_loss: 0.3369 - val_acc: 0.9966 - val_dice_coef: 0.3531
#
# Epoch 00039: val_loss did not improve from 0.31986
# Epoch 40/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0860 - acc: 0.9990 - dice_coef: 0.8335 - val_loss: 0.3344 - val_acc: 0.9966 - val_dice_coef: 0.3580
#
# Epoch 00040: val_loss did not improve from 0.31986
# Epoch 41/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0825 - acc: 0.9991 - dice_coef: 0.8404 - val_loss: 0.3359 - val_acc: 0.9966 - val_dice_coef: 0.3552
#
# Epoch 00041: val_loss did not improve from 0.31986
# Epoch 42/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0849 - acc: 0.9991 - dice_coef: 0.8358 - val_loss: 0.3350 - val_acc: 0.9966 - val_dice_coef: 0.3569
#
# Epoch 00042: val_loss did not improve from 0.31986
# Epoch 43/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0846 - acc: 0.9991 - dice_coef: 0.8363 - val_loss: 0.3360 - val_acc: 0.9966 - val_dice_coef: 0.3549
#
# Epoch 00043: val_loss did not improve from 0.31986
# Epoch 44/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0840 - acc: 0.9991 - dice_coef: 0.8374 - val_loss: 0.3376 - val_acc: 0.9966 - val_dice_coef: 0.3518
#
# Epoch 00044: val_loss did not improve from 0.31986
# Epoch 45/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0842 - acc: 0.9991 - dice_coef: 0.8370 - val_loss: 0.3350 - val_acc: 0.9966 - val_dice_coef: 0.3572
#
# Epoch 00045: val_loss did not improve from 0.31986
# Epoch 46/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0854 - acc: 0.9991 - dice_coef: 0.8348 - val_loss: 0.3318 - val_acc: 0.9965 - val_dice_coef: 0.3635
#
# Epoch 00046: val_loss did not improve from 0.31986
# Epoch 47/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0828 - acc: 0.9991 - dice_coef: 0.8399 - val_loss: 0.3339 - val_acc: 0.9966 - val_dice_coef: 0.3592
#
# Epoch 00047: val_loss did not improve from 0.31986
# Epoch 48/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0839 - acc: 0.9991 - dice_coef: 0.8377 - val_loss: 0.3377 - val_acc: 0.9966 - val_dice_coef: 0.3516
#
# Epoch 00048: val_loss did not improve from 0.31986
# Epoch 49/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0838 - acc: 0.9991 - dice_coef: 0.8379 - val_loss: 0.3358 - val_acc: 0.9966 - val_dice_coef: 0.3558
#
# Epoch 00049: val_loss did not improve from 0.31986
# Epoch 50/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0829 - acc: 0.9991 - dice_coef: 0.8397 - val_loss: 0.3378 - val_acc: 0.9966 - val_dice_coef: 0.3518
#
# Epoch 00050: val_loss did not improve from 0.31986
# Epoch 51/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0839 - acc: 0.9991 - dice_coef: 0.8377 - val_loss: 0.3344 - val_acc: 0.9966 - val_dice_coef: 0.3586
#
# Epoch 00051: val_loss did not improve from 0.31986
# Epoch 52/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0812 - acc: 0.9991 - dice_coef: 0.8429 - val_loss: 0.3365 - val_acc: 0.9966 - val_dice_coef: 0.3544
#
# Epoch 00052: val_loss did not improve from 0.31986
# Epoch 53/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0831 - acc: 0.9991 - dice_coef: 0.8392 - val_loss: 0.3355 - val_acc: 0.9966 - val_dice_coef: 0.3564
#
# Epoch 00053: val_loss did not improve from 0.31986
# Epoch 54/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0814 - acc: 0.9991 - dice_coef: 0.8425 - val_loss: 0.3339 - val_acc: 0.9966 - val_dice_coef: 0.3596
#
# Epoch 00054: val_loss did not improve from 0.31986
# Epoch 55/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0803 - acc: 0.9991 - dice_coef: 0.8447 - val_loss: 0.3311 - val_acc: 0.9966 - val_dice_coef: 0.3653
#
# Epoch 00055: val_loss did not improve from 0.31986
# Epoch 56/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0815 - acc: 0.9991 - dice_coef: 0.8424 - val_loss: 0.3325 - val_acc: 0.9966 - val_dice_coef: 0.3626
#
# Epoch 00056: val_loss did not improve from 0.31986
# Epoch 57/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0805 - acc: 0.9991 - dice_coef: 0.8443 - val_loss: 0.3331 - val_acc: 0.9966 - val_dice_coef: 0.3615
#
# Epoch 00057: val_loss did not improve from 0.31986
# Epoch 58/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0807 - acc: 0.9991 - dice_coef: 0.8440 - val_loss: 0.3335 - val_acc: 0.9966 - val_dice_coef: 0.3608
#
# Epoch 00058: val_loss did not improve from 0.31986
# Epoch 59/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0802 - acc: 0.9991 - dice_coef: 0.8448 - val_loss: 0.3346 - val_acc: 0.9966 - val_dice_coef: 0.3585
#
# Epoch 00059: val_loss did not improve from 0.31986
# Epoch 60/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0791 - acc: 0.9991 - dice_coef: 0.8470 - val_loss: 0.3350 - val_acc: 0.9966 - val_dice_coef: 0.3578
#
# Epoch 00060: val_loss did not improve from 0.31986
# Epoch 61/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0797 - acc: 0.9991 - dice_coef: 0.8459 - val_loss: 0.3377 - val_acc: 0.9966 - val_dice_coef: 0.3524
#
# Epoch 00061: val_loss did not improve from 0.31986
# Epoch 62/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0790 - acc: 0.9991 - dice_coef: 0.8472 - val_loss: 0.3348 - val_acc: 0.9966 - val_dice_coef: 0.3583
#
# Epoch 00062: val_loss did not improve from 0.31986
# Epoch 63/100
# 1589/1589 [==============================] - 33s 21ms/step - loss: 0.0790 - acc: 0.9991 - dice_coef: 0.8473 - val_loss: 0.3354 - val_acc: 0.9966 - val_dice_coef: 0.3570
#
# Epoch 00063: val_loss did not improve from 0.31986
# Epoch 64/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0787 - acc: 0.9991 - dice_coef: 0.8478 - val_loss: 0.3339 - val_acc: 0.9966 - val_dice_coef: 0.3603
#
# Epoch 00064: val_loss did not improve from 0.31986
# Epoch 65/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0782 - acc: 0.9991 - dice_coef: 0.8488 - val_loss: 0.3372 - val_acc: 0.9966 - val_dice_coef: 0.3537
#
# Epoch 00065: val_loss did not improve from 0.31986
# Epoch 66/100
# 1589/1589 [==============================] - 33s 21ms/step - loss: 0.0783 - acc: 0.9991 - dice_coef: 0.8487 - val_loss: 0.3340 - val_acc: 0.9965 - val_dice_coef: 0.3602
#
# Epoch 00066: val_loss did not improve from 0.31986
# Epoch 67/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0792 - acc: 0.9991 - dice_coef: 0.8470 - val_loss: 0.3346 - val_acc: 0.9966 - val_dice_coef: 0.3589
#
# Epoch 00067: val_loss did not improve from 0.31986
# Epoch 68/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0772 - acc: 0.9991 - dice_coef: 0.8507 - val_loss: 0.3331 - val_acc: 0.9966 - val_dice_coef: 0.3619
#
# Epoch 00068: val_loss did not improve from 0.31986
# Epoch 69/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0767 - acc: 0.9991 - dice_coef: 0.8517 - val_loss: 0.3351 - val_acc: 0.9966 - val_dice_coef: 0.3579
#
# Epoch 00069: val_loss did not improve from 0.31986
# Epoch 70/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0777 - acc: 0.9991 - dice_coef: 0.8498 - val_loss: 0.3355 - val_acc: 0.9966 - val_dice_coef: 0.3573
#
# Epoch 00070: val_loss did not improve from 0.31986
# Epoch 71/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0777 - acc: 0.9991 - dice_coef: 0.8498 - val_loss: 0.3328 - val_acc: 0.9966 - val_dice_coef: 0.3626
#
# Epoch 00071: val_loss did not improve from 0.31986
# Epoch 72/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0776 - acc: 0.9991 - dice_coef: 0.8500 - val_loss: 0.3352 - val_acc: 0.9966 - val_dice_coef: 0.3579
#
# Epoch 00072: val_loss did not improve from 0.31986
# Epoch 73/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0763 - acc: 0.9991 - dice_coef: 0.8526 - val_loss: 0.3361 - val_acc: 0.9966 - val_dice_coef: 0.3562
#
# Epoch 00073: val_loss did not improve from 0.31986
# Epoch 74/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0768 - acc: 0.9991 - dice_coef: 0.8516 - val_loss: 0.3376 - val_acc: 0.9966 - val_dice_coef: 0.3533
#
# Epoch 00074: val_loss did not improve from 0.31986
# Epoch 75/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0768 - acc: 0.9991 - dice_coef: 0.8517 - val_loss: 0.3367 - val_acc: 0.9966 - val_dice_coef: 0.3551
#
# Epoch 00075: val_loss did not improve from 0.31986
# Epoch 76/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0760 - acc: 0.9992 - dice_coef: 0.8533 - val_loss: 0.3317 - val_acc: 0.9966 - val_dice_coef: 0.3652
#
# Epoch 00076: val_loss did not improve from 0.31986
# Epoch 77/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0764 - acc: 0.9991 - dice_coef: 0.8523 - val_loss: 0.3320 - val_acc: 0.9966 - val_dice_coef: 0.3645
#
# Epoch 00077: val_loss did not improve from 0.31986
# Epoch 78/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0759 - acc: 0.9992 - dice_coef: 0.8535 - val_loss: 0.3323 - val_acc: 0.9966 - val_dice_coef: 0.3640
#
# Epoch 00078: val_loss did not improve from 0.31986
# Epoch 79/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0742 - acc: 0.9992 - dice_coef: 0.8567 - val_loss: 0.3355 - val_acc: 0.9966 - val_dice_coef: 0.3576
#
# Epoch 00079: val_loss did not improve from 0.31986
# Epoch 80/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0734 - acc: 0.9992 - dice_coef: 0.8581 - val_loss: 0.3326 - val_acc: 0.9966 - val_dice_coef: 0.3634
#
# Epoch 00080: val_loss did not improve from 0.31986
# Epoch 81/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0757 - acc: 0.9992 - dice_coef: 0.8537 - val_loss: 0.3334 - val_acc: 0.9966 - val_dice_coef: 0.3620
#
# Epoch 00081: val_loss did not improve from 0.31986
# Epoch 82/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0749 - acc: 0.9992 - dice_coef: 0.8554 - val_loss: 0.3302 - val_acc: 0.9966 - val_dice_coef: 0.3683
#
# Epoch 00082: val_loss did not improve from 0.31986
# Epoch 83/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0750 - acc: 0.9992 - dice_coef: 0.8552 - val_loss: 0.3359 - val_acc: 0.9966 - val_dice_coef: 0.3570
#
# Epoch 00083: val_loss did not improve from 0.31986
# Epoch 84/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0734 - acc: 0.9992 - dice_coef: 0.8583 - val_loss: 0.3304 - val_acc: 0.9966 - val_dice_coef: 0.3682
#
# Epoch 00084: val_loss did not improve from 0.31986
# Epoch 85/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0738 - acc: 0.9992 - dice_coef: 0.8576 - val_loss: 0.3327 - val_acc: 0.9966 - val_dice_coef: 0.3634
#
# Epoch 00085: val_loss did not improve from 0.31986
# Epoch 86/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0730 - acc: 0.9992 - dice_coef: 0.8591 - val_loss: 0.3340 - val_acc: 0.9966 - val_dice_coef: 0.3610
#
# Epoch 00086: val_loss did not improve from 0.31986
# Epoch 87/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0726 - acc: 0.9992 - dice_coef: 0.8599 - val_loss: 0.3321 - val_acc: 0.9966 - val_dice_coef: 0.3649
#
# Epoch 00087: val_loss did not improve from 0.31986
# Epoch 88/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0733 - acc: 0.9992 - dice_coef: 0.8585 - val_loss: 0.3319 - val_acc: 0.9966 - val_dice_coef: 0.3653
#
# Epoch 00088: val_loss did not improve from 0.31986
# Epoch 89/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0715 - acc: 0.9992 - dice_coef: 0.8619 - val_loss: 0.3325 - val_acc: 0.9966 - val_dice_coef: 0.3641
#
# Epoch 00089: val_loss did not improve from 0.31986
# Epoch 90/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0733 - acc: 0.9992 - dice_coef: 0.8585 - val_loss: 0.3320 - val_acc: 0.9966 - val_dice_coef: 0.3652
#
# Epoch 00090: val_loss did not improve from 0.31986
# Epoch 91/100
# 1589/1589 [==============================] - 33s 21ms/step - loss: 0.0728 - acc: 0.9992 - dice_coef: 0.8596 - val_loss: 0.3325 - val_acc: 0.9966 - val_dice_coef: 0.3641
#
# Epoch 00091: val_loss did not improve from 0.31986
# Epoch 92/100
# 1589/1589 [==============================] - 33s 21ms/step - loss: 0.0717 - acc: 0.9992 - dice_coef: 0.8615 - val_loss: 0.3308 - val_acc: 0.9966 - val_dice_coef: 0.3677
#
# Epoch 00092: val_loss did not improve from 0.31986
# Epoch 93/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0720 - acc: 0.9992 - dice_coef: 0.8611 - val_loss: 0.3317 - val_acc: 0.9966 - val_dice_coef: 0.3659
#
# Epoch 00093: val_loss did not improve from 0.31986
# Epoch 94/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0722 - acc: 0.9992 - dice_coef: 0.8606 - val_loss: 0.3335 - val_acc: 0.9966 - val_dice_coef: 0.3623
#
# Epoch 00094: val_loss did not improve from 0.31986
# Epoch 95/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0713 - acc: 0.9992 - dice_coef: 0.8624 - val_loss: 0.3290 - val_acc: 0.9966 - val_dice_coef: 0.3715
#
# Epoch 00095: val_loss did not improve from 0.31986
# Epoch 96/100
# 1589/1589 [==============================] - 34s 21ms/step - loss: 0.0715 - acc: 0.9992 - dice_coef: 0.8619 - val_loss: 0.3290 - val_acc: 0.9966 - val_dice_coef: 0.3715
#
# Epoch 00096: val_loss did not improve from 0.31986
# Epoch 97/100
# 1589/1589 [==============================] - 33s 21ms/step - loss: 0.0702 - acc: 0.9992 - dice_coef: 0.8645 - val_loss: 0.3339 - val_acc: 0.9966 - val_dice_coef: 0.3616
#
# Epoch 00097: val_loss did not improve from 0.31986
# Epoch 98/100
# 1589/1589 [==============================] - 33s 21ms/step - loss: 0.0705 - acc: 0.9992 - dice_coef: 0.8639 - val_loss: 0.3316 - val_acc: 0.9966 - val_dice_coef: 0.3664
#
# Epoch 00098: val_loss did not improve from 0.31986
# Epoch 99/100
# 1589/1589 [==============================] - 33s 21ms/step - loss: 0.0702 - acc: 0.9992 - dice_coef: 0.8645 - val_loss: 0.3345 - val_acc: 0.9966 - val_dice_coef: 0.3606
#
# Epoch 00099: val_loss did not improve from 0.31986
# Epoch 100/100
# 1589/1589 [==============================] - 33s 21ms/step - loss: 0.0708 - acc: 0.9992 - dice_coef: 0.8635 - val_loss: 0.3323 - val_acc: 0.9966 - val_dice_coef: 0.3650
#
# Epoch 00100: val_loss did not improve from 0.31986

# %%
# data augmentation

results_aug = model_aug.fit(X_train_aug, y_train_aug,
                            batch_size=16, epochs=100, 
                            callbacks=callbacks_aug, 
                            validation_data=(X_valid_aug, y_valid_aug))
# Out:
# W0627 18:05:15.226074 35432 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0627 18:05:15.732913 35432 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# W0627 18:05:16.357800 35432 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
# Train on 15890 samples, validate on 15890 samples
# Epoch 1/100
# W0627 18:05:17.956532 35432 module_wrapper.py:139] From C:\ProgramData\Anaconda3\envs\segway\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# 15890/15890 [==============================] - 449s 28ms/step - loss: 0.4166 - acc: 0.9913 - dice_coef: 0.2356 - val_loss: 0.3180 - val_acc: 0.9940 - val_dice_coef: 0.3940
#
# Epoch 00001: val_loss improved from inf to 0.31803, saving model to ../res/u-net_aug.h5
# Epoch 2/100
# 15890/15890 [==============================] - 431s 27ms/step - loss: 0.2725 - acc: 0.9955 - dice_coef: 0.4768 - val_loss: 0.2768 - val_acc: 0.9952 - val_dice_coef: 0.4683
#
# Epoch 00002: val_loss improved from 0.31803 to 0.27679, saving model to ../res/u-net_aug.h5
# Epoch 3/100
# 15890/15890 [==============================] - 435s 27ms/step - loss: 0.2456 - acc: 0.9961 - dice_coef: 0.5287 - val_loss: 0.2547 - val_acc: 0.9955 - val_dice_coef: 0.5100
#
# Epoch 00003: val_loss improved from 0.27679 to 0.25472, saving model to ../res/u-net_aug.h5
# Epoch 4/100
# 15890/15890 [==============================] - 431s 27ms/step - loss: 0.2234 - acc: 0.9965 - dice_coef: 0.5712 - val_loss: 0.2308 - val_acc: 0.9965 - val_dice_coef: 0.5558
#
# Epoch 00004: val_loss improved from 0.25472 to 0.23082, saving model to ../res/u-net_aug.h5
# Epoch 5/100
# 15890/15890 [==============================] - 433s 27ms/step - loss: 0.2021 - acc: 0.9970 - dice_coef: 0.6123 - val_loss: 0.1987 - val_acc: 0.9976 - val_dice_coef: 0.6155
#
# Epoch 00005: val_loss improved from 0.23082 to 0.19866, saving model to ../res/u-net_aug.h5
# Epoch 6/100
# 15890/15890 [==============================] - 432s 27ms/step - loss: 0.1781 - acc: 0.9975 - dice_coef: 0.6584 - val_loss: 0.1935 - val_acc: 0.9979 - val_dice_coef: 0.6264
#
# Epoch 00006: val_loss improved from 0.19866 to 0.19348, saving model to ../res/u-net_aug.h5
# Epoch 7/100
# 15890/15890 [==============================] - 433s 27ms/step - loss: 0.1608 - acc: 0.9978 - dice_coef: 0.6918 - val_loss: 0.1580 - val_acc: 0.9981 - val_dice_coef: 0.6955
#
# Epoch 00007: val_loss improved from 0.19348 to 0.15803, saving model to ../res/u-net_aug.h5
# Epoch 8/100
# 15890/15890 [==============================] - 432s 27ms/step - loss: 0.1438 - acc: 0.9980 - dice_coef: 0.7245 - val_loss: 0.1452 - val_acc: 0.9982 - val_dice_coef: 0.7200
#
# Epoch 00008: val_loss improved from 0.15803 to 0.14524, saving model to ../res/u-net_aug.h5
# Epoch 9/100
# 15890/15890 [==============================] - 432s 27ms/step - loss: 0.1303 - acc: 0.9982 - dice_coef: 0.7505 - val_loss: 0.1288 - val_acc: 0.9985 - val_dice_coef: 0.7522
#
# Epoch 00009: val_loss improved from 0.14524 to 0.12885, saving model to ../res/u-net_aug.h5
# Epoch 10/100
# 15890/15890 [==============================] - 431s 27ms/step - loss: 0.1182 - acc: 0.9984 - dice_coef: 0.7739 - val_loss: 0.1215 - val_acc: 0.9986 - val_dice_coef: 0.7661
#
# Epoch 00010: val_loss improved from 0.12885 to 0.12154, saving model to ../res/u-net_aug.h5
# Epoch 11/100
# 15890/15890 [==============================] - 431s 27ms/step - loss: 0.1086 - acc: 0.9985 - dice_coef: 0.7922 - val_loss: 0.1143 - val_acc: 0.9987 - val_dice_coef: 0.7796
#
# Epoch 00011: val_loss improved from 0.12154 to 0.11428, saving model to ../res/u-net_aug.h5
# Epoch 12/100
# 15890/15890 [==============================] - 432s 27ms/step - loss: 0.1014 - acc: 0.9986 - dice_coef: 0.8061 - val_loss: 0.1049 - val_acc: 0.9988 - val_dice_coef: 0.7980
#
# Epoch 00012: val_loss improved from 0.11428 to 0.10494, saving model to ../res/u-net_aug.h5
# Epoch 13/100
# 15890/15890 [==============================] - 429s 27ms/step - loss: 0.0961 - acc: 0.9987 - dice_coef: 0.8164 - val_loss: 0.0887 - val_acc: 0.9990 - val_dice_coef: 0.8296
#
# Epoch 00013: val_loss improved from 0.10494 to 0.08875, saving model to ../res/u-net_aug.h5
# Epoch 14/100
# 15890/15890 [==============================] - 434s 27ms/step - loss: 0.0902 - acc: 0.9988 - dice_coef: 0.8276 - val_loss: 0.0882 - val_acc: 0.9990 - val_dice_coef: 0.8304
#
# Epoch 00014: val_loss improved from 0.08875 to 0.08818, saving model to ../res/u-net_aug.h5
# Epoch 15/100
# 15890/15890 [==============================] - 429s 27ms/step - loss: 0.0845 - acc: 0.9989 - dice_coef: 0.8386 - val_loss: 0.0861 - val_acc: 0.9991 - val_dice_coef: 0.8344
#
# Epoch 00015: val_loss improved from 0.08818 to 0.08611, saving model to ../res/u-net_aug.h5
# Epoch 16/100
# 15890/15890 [==============================] - 433s 27ms/step - loss: 0.0810 - acc: 0.9989 - dice_coef: 0.8452 - val_loss: 0.0784 - val_acc: 0.9991 - val_dice_coef: 0.8493
#
# Epoch 00016: val_loss improved from 0.08611 to 0.07837, saving model to ../res/u-net_aug.h5
# Epoch 17/100
# 15890/15890 [==============================] - 430s 27ms/step - loss: 0.0781 - acc: 0.9990 - dice_coef: 0.8507 - val_loss: 0.0819 - val_acc: 0.9991 - val_dice_coef: 0.8423
#
# Epoch 00017: val_loss did not improve from 0.07837
# Epoch 18/100
# 15890/15890 [==============================] - 433s 27ms/step - loss: 0.0747 - acc: 0.9990 - dice_coef: 0.8573 - val_loss: 0.0803 - val_acc: 0.9991 - val_dice_coef: 0.8456
#
# Epoch 00018: val_loss did not improve from 0.07837
# Epoch 19/100
# 15890/15890 [==============================] - 430s 27ms/step - loss: 0.0720 - acc: 0.9990 - dice_coef: 0.8626 - val_loss: 0.0691 - val_acc: 0.9992 - val_dice_coef: 0.8672
#
# Epoch 00019: val_loss improved from 0.07837 to 0.06914, saving model to ../res/u-net_aug.h5
# Epoch 20/100
# 15890/15890 [==============================] - 434s 27ms/step - loss: 0.0682 - acc: 0.9991 - dice_coef: 0.8698 - val_loss: 0.0633 - val_acc: 0.9992 - val_dice_coef: 0.8783
#
# Epoch 00020: val_loss improved from 0.06914 to 0.06326, saving model to ../res/u-net_aug.h5
# Epoch 21/100
# 15890/15890 [==============================] - 432s 27ms/step - loss: 0.0663 - acc: 0.9991 - dice_coef: 0.8734 - val_loss: 0.0711 - val_acc: 0.9991 - val_dice_coef: 0.8633
#
# Epoch 00021: val_loss did not improve from 0.06326
# Epoch 22/100
# 15890/15890 [==============================] - 433s 27ms/step - loss: 0.0638 - acc: 0.9991 - dice_coef: 0.8781 - val_loss: 0.0631 - val_acc: 0.9993 - val_dice_coef: 0.8788
#
# Epoch 00022: val_loss improved from 0.06326 to 0.06306, saving model to ../res/u-net_aug.h5
# Epoch 23/100
# 15890/15890 [==============================] - 430s 27ms/step - loss: 0.0632 - acc: 0.9992 - dice_coef: 0.8793 - val_loss: 0.0663 - val_acc: 0.9992 - val_dice_coef: 0.8728
#
# Epoch 00023: val_loss did not improve from 0.06306
# Epoch 24/100
# 15890/15890 [==============================] - 433s 27ms/step - loss: 0.0607 - acc: 0.9992 - dice_coef: 0.8841 - val_loss: 0.0648 - val_acc: 0.9992 - val_dice_coef: 0.8754
#
# Epoch 00024: val_loss did not improve from 0.06306
# Epoch 25/100
# 15890/15890 [==============================] - 431s 27ms/step - loss: 0.0590 - acc: 0.9992 - dice_coef: 0.8874 - val_loss: 0.0576 - val_acc: 0.9993 - val_dice_coef: 0.8895
#
# Epoch 00025: val_loss improved from 0.06306 to 0.05761, saving model to ../res/u-net_aug.h5
# Epoch 26/100
# 15890/15890 [==============================] - 431s 27ms/step - loss: 0.0576 - acc: 0.9992 - dice_coef: 0.8900 - val_loss: 0.0536 - val_acc: 0.9994 - val_dice_coef: 0.8968
#
# Epoch 00026: val_loss improved from 0.05761 to 0.05362, saving model to ../res/u-net_aug.h5
# Epoch 27/100
# 15890/15890 [==============================] - 431s 27ms/step - loss: 0.0575 - acc: 0.9992 - dice_coef: 0.8902 - val_loss: 0.0557 - val_acc: 0.9993 - val_dice_coef: 0.8930
#
# Epoch 00027: val_loss did not improve from 0.05362
# Epoch 28/100
# 15890/15890 [==============================] - 430s 27ms/step - loss: 0.0550 - acc: 0.9993 - dice_coef: 0.8949 - val_loss: 0.0559 - val_acc: 0.9993 - val_dice_coef: 0.8926
#
# Epoch 00028: val_loss did not improve from 0.05362
# Epoch 29/100
# 15890/15890 [==============================] - 432s 27ms/step - loss: 0.0526 - acc: 0.9993 - dice_coef: 0.8995 - val_loss: 0.0469 - val_acc: 0.9994 - val_dice_coef: 0.9099
#
# Epoch 00029: val_loss improved from 0.05362 to 0.04692, saving model to ../res/u-net_aug.h5
# Epoch 30/100
# 15890/15890 [==============================] - 428s 27ms/step - loss: 0.0516 - acc: 0.9993 - dice_coef: 0.9014 - val_loss: 0.0515 - val_acc: 0.9994 - val_dice_coef: 0.9010
#
# Epoch 00030: val_loss did not improve from 0.04692
# Epoch 31/100
# 15890/15890 [==============================] - 432s 27ms/step - loss: 0.0516 - acc: 0.9993 - dice_coef: 0.9013 - val_loss: 0.0480 - val_acc: 0.9994 - val_dice_coef: 0.9078
#
# Epoch 00031: val_loss did not improve from 0.04692
# Epoch 32/100
# 15890/15890 [==============================] - 428s 27ms/step - loss: 0.0501 - acc: 0.9993 - dice_coef: 0.9043 - val_loss: 0.0460 - val_acc: 0.9994 - val_dice_coef: 0.9115
#
# Epoch 00032: val_loss improved from 0.04692 to 0.04605, saving model to ../res/u-net_aug.h5
# Epoch 33/100
# 15890/15890 [==============================] - 432s 27ms/step - loss: 0.0481 - acc: 0.9993 - dice_coef: 0.9080 - val_loss: 0.0419 - val_acc: 0.9995 - val_dice_coef: 0.9197
#
# Epoch 00033: val_loss improved from 0.04605 to 0.04185, saving model to ../res/u-net_aug.h5
# Epoch 34/100
# 15890/15890 [==============================] - 429s 27ms/step - loss: 0.0471 - acc: 0.9994 - dice_coef: 0.9100 - val_loss: 0.0484 - val_acc: 0.9994 - val_dice_coef: 0.9070
#
# Epoch 00034: val_loss did not improve from 0.04185
# Epoch 35/100
# 15890/15890 [==============================] - 432s 27ms/step - loss: 0.0483 - acc: 0.9993 - dice_coef: 0.9076 - val_loss: 0.0416 - val_acc: 0.9995 - val_dice_coef: 0.9201
#
# Epoch 00035: val_loss improved from 0.04185 to 0.04163, saving model to ../res/u-net_aug.h5
# Epoch 36/100
# 15890/15890 [==============================] - 429s 27ms/step - loss: 0.0467 - acc: 0.9994 - dice_coef: 0.9107 - val_loss: 0.0425 - val_acc: 0.9995 - val_dice_coef: 0.9185
#
# Epoch 00036: val_loss did not improve from 0.04163
# Epoch 37/100
# 15890/15890 [==============================] - 432s 27ms/step - loss: 0.0451 - acc: 0.9994 - dice_coef: 0.9137 - val_loss: 0.0406 - val_acc: 0.9995 - val_dice_coef: 0.9220
#
# Epoch 00037: val_loss improved from 0.04163 to 0.04056, saving model to ../res/u-net_aug.h5
# Epoch 38/100
# 15890/15890 [==============================] - 431s 27ms/step - loss: 0.0442 - acc: 0.9994 - dice_coef: 0.9156 - val_loss: 0.0417 - val_acc: 0.9995 - val_dice_coef: 0.9200
#
# Epoch 00038: val_loss did not improve from 0.04056
# Epoch 39/100
# 15890/15890 [==============================] - 433s 27ms/step - loss: 0.0430 - acc: 0.9994 - dice_coef: 0.9178 - val_loss: 0.0424 - val_acc: 0.9995 - val_dice_coef: 0.9184
#
# Epoch 00039: val_loss did not improve from 0.04056
# Epoch 40/100
# 15890/15890 [==============================] - 432s 27ms/step - loss: 0.0433 - acc: 0.9994 - dice_coef: 0.9173 - val_loss: 0.0422 - val_acc: 0.9995 - val_dice_coef: 0.9190
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00040: val_loss did not improve from 0.04056
# Epoch 41/100
# 15890/15890 [==============================] - 432s 27ms/step - loss: 0.0365 - acc: 0.9995 - dice_coef: 0.9302 - val_loss: 0.0336 - val_acc: 0.9996 - val_dice_coef: 0.9355
#
# Epoch 00041: val_loss improved from 0.04056 to 0.03361, saving model to ../res/u-net_aug.h5
# Epoch 42/100
# 15890/15890 [==============================] - 430s 27ms/step - loss: 0.0348 - acc: 0.9995 - dice_coef: 0.9334 - val_loss: 0.0330 - val_acc: 0.9996 - val_dice_coef: 0.9366
#
# Epoch 00042: val_loss improved from 0.03361 to 0.03300, saving model to ../res/u-net_aug.h5
# Epoch 43/100
# 15890/15890 [==============================] - 431s 27ms/step - loss: 0.0340 - acc: 0.9995 - dice_coef: 0.9350 - val_loss: 0.0325 - val_acc: 0.9996 - val_dice_coef: 0.9377
#
# Epoch 00043: val_loss improved from 0.03300 to 0.03245, saving model to ../res/u-net_aug.h5
# Epoch 44/100
# 15890/15890 [==============================] - 431s 27ms/step - loss: 0.0336 - acc: 0.9995 - dice_coef: 0.9358 - val_loss: 0.0319 - val_acc: 0.9996 - val_dice_coef: 0.9388
#
# Epoch 00044: val_loss improved from 0.03245 to 0.03188, saving model to ../res/u-net_aug.h5
# Epoch 45/100
# 15890/15890 [==============================] - 429s 27ms/step - loss: 0.0328 - acc: 0.9996 - dice_coef: 0.9373 - val_loss: 0.0316 - val_acc: 0.9996 - val_dice_coef: 0.9394
#
# Epoch 00045: val_loss improved from 0.03188 to 0.03158, saving model to ../res/u-net_aug.h5
# Epoch 46/100
# 15890/15890 [==============================] - 433s 27ms/step - loss: 0.0324 - acc: 0.9996 - dice_coef: 0.9380 - val_loss: 0.0312 - val_acc: 0.9996 - val_dice_coef: 0.9401
#
# Epoch 00046: val_loss improved from 0.03158 to 0.03119, saving model to ../res/u-net_aug.h5
# Epoch 47/100
# 15890/15890 [==============================] - 429s 27ms/step - loss: 0.0320 - acc: 0.9996 - dice_coef: 0.9387 - val_loss: 0.0308 - val_acc: 0.9996 - val_dice_coef: 0.9408
#
# Epoch 00047: val_loss improved from 0.03119 to 0.03084, saving model to ../res/u-net_aug.h5
# Epoch 48/100
# 15890/15890 [==============================] - 433s 27ms/step - loss: 0.0316 - acc: 0.9996 - dice_coef: 0.9395 - val_loss: 0.0305 - val_acc: 0.9996 - val_dice_coef: 0.9414
#
# Epoch 00048: val_loss improved from 0.03084 to 0.03054, saving model to ../res/u-net_aug.h5
# Epoch 49/100
# 15890/15890 [==============================] - 430s 27ms/step - loss: 0.0312 - acc: 0.9996 - dice_coef: 0.9403 - val_loss: 0.0302 - val_acc: 0.9996 - val_dice_coef: 0.9420
#
# Epoch 00049: val_loss improved from 0.03054 to 0.03019, saving model to ../res/u-net_aug.h5
# Epoch 50/100
# 15890/15890 [==============================] - 433s 27ms/step - loss: 0.0310 - acc: 0.9996 - dice_coef: 0.9407 - val_loss: 0.0299 - val_acc: 0.9996 - val_dice_coef: 0.9426
#
# Epoch 00050: val_loss improved from 0.03019 to 0.02989, saving model to ../res/u-net_aug.h5
# Epoch 51/100
# 15890/15890 [==============================] - 429s 27ms/step - loss: 0.0308 - acc: 0.9996 - dice_coef: 0.9410 - val_loss: 0.0298 - val_acc: 0.9996 - val_dice_coef: 0.9429
#
# Epoch 00051: val_loss improved from 0.02989 to 0.02976, saving model to ../res/u-net_aug.h5
# Epoch 52/100
# 15890/15890 [==============================] - 433s 27ms/step - loss: 0.0304 - acc: 0.9996 - dice_coef: 0.9419 - val_loss: 0.0295 - val_acc: 0.9996 - val_dice_coef: 0.9434
#
# Epoch 00052: val_loss improved from 0.02976 to 0.02947, saving model to ../res/u-net_aug.h5
# Epoch 53/100
# 15890/15890 [==============================] - 431s 27ms/step - loss: 0.0303 - acc: 0.9996 - dice_coef: 0.9421 - val_loss: 0.0291 - val_acc: 0.9996 - val_dice_coef: 0.9441
#
# Epoch 00053: val_loss improved from 0.02947 to 0.02911, saving model to ../res/u-net_aug.h5
# Epoch 54/100
# 15890/15890 [==============================] - 433s 27ms/step - loss: 0.0300 - acc: 0.9996 - dice_coef: 0.9427 - val_loss: 0.0288 - val_acc: 0.9996 - val_dice_coef: 0.9448
#
# Epoch 00054: val_loss improved from 0.02911 to 0.02876, saving model to ../res/u-net_aug.h5
# Epoch 55/100
# 15890/15890 [==============================] - 430s 27ms/step - loss: 0.0299 - acc: 0.9996 - dice_coef: 0.9429 - val_loss: 0.0286 - val_acc: 0.9996 - val_dice_coef: 0.9451
#
# Epoch 00055: val_loss improved from 0.02876 to 0.02859, saving model to ../res/u-net_aug.h5
# Epoch 56/100
# 15890/15890 [==============================] - 432s 27ms/step - loss: 0.0296 - acc: 0.9996 - dice_coef: 0.9433 - val_loss: 0.0285 - val_acc: 0.9996 - val_dice_coef: 0.9453
#
# Epoch 00056: val_loss improved from 0.02859 to 0.02848, saving model to ../res/u-net_aug.h5
# Epoch 57/100
# 15890/15890 [==============================] - 429s 27ms/step - loss: 0.0293 - acc: 0.9996 - dice_coef: 0.9440 - val_loss: 0.0279 - val_acc: 0.9997 - val_dice_coef: 0.9464
#
# Epoch 00057: val_loss improved from 0.02848 to 0.02793, saving model to ../res/u-net_aug.h5
# Epoch 58/100
# 15890/15890 [==============================] - 430s 27ms/step - loss: 0.0291 - acc: 0.9996 - dice_coef: 0.9444 - val_loss: 0.0278 - val_acc: 0.9997 - val_dice_coef: 0.9467
#
# Epoch 00058: val_loss improved from 0.02793 to 0.02776, saving model to ../res/u-net_aug.h5
# Epoch 59/100
# 15890/15890 [==============================] - 428s 27ms/step - loss: 0.0290 - acc: 0.9996 - dice_coef: 0.9446 - val_loss: 0.0274 - val_acc: 0.9997 - val_dice_coef: 0.9473
#
# Epoch 00059: val_loss improved from 0.02776 to 0.02742, saving model to ../res/u-net_aug.h5
# Epoch 60/100
# 15890/15890 [==============================] - 429s 27ms/step - loss: 0.0287 - acc: 0.9996 - dice_coef: 0.9450 - val_loss: 0.0272 - val_acc: 0.9997 - val_dice_coef: 0.9478
#
# Epoch 00060: val_loss improved from 0.02742 to 0.02719, saving model to ../res/u-net_aug.h5
# Epoch 61/100
# 15890/15890 [==============================] - 429s 27ms/step - loss: 0.0285 - acc: 0.9996 - dice_coef: 0.9455 - val_loss: 0.0270 - val_acc: 0.9997 - val_dice_coef: 0.9482
#
# Epoch 00061: val_loss improved from 0.02719 to 0.02697, saving model to ../res/u-net_aug.h5
# Epoch 62/100
# 15890/15890 [==============================] - 426s 27ms/step - loss: 0.0284 - acc: 0.9996 - dice_coef: 0.9456 - val_loss: 0.0268 - val_acc: 0.9997 - val_dice_coef: 0.9484
#
# Epoch 00062: val_loss improved from 0.02697 to 0.02684, saving model to ../res/u-net_aug.h5
# Epoch 63/100
# 15890/15890 [==============================] - 430s 27ms/step - loss: 0.0282 - acc: 0.9996 - dice_coef: 0.9461 - val_loss: 0.0265 - val_acc: 0.9997 - val_dice_coef: 0.9490
#
# Epoch 00063: val_loss improved from 0.02684 to 0.02654, saving model to ../res/u-net_aug.h5
# Epoch 64/100
# 15890/15890 [==============================] - 426s 27ms/step - loss: 0.0281 - acc: 0.9996 - dice_coef: 0.9463 - val_loss: 0.0265 - val_acc: 0.9997 - val_dice_coef: 0.9492
#
# Epoch 00064: val_loss improved from 0.02654 to 0.02646, saving model to ../res/u-net_aug.h5
# Epoch 65/100
# 15890/15890 [==============================] - 430s 27ms/step - loss: 0.0279 - acc: 0.9996 - dice_coef: 0.9466 - val_loss: 0.0262 - val_acc: 0.9997 - val_dice_coef: 0.9498
#
# Epoch 00065: val_loss improved from 0.02646 to 0.02615, saving model to ../res/u-net_aug.h5
# Epoch 66/100
# 15890/15890 [==============================] - 429s 27ms/step - loss: 0.0277 - acc: 0.9996 - dice_coef: 0.9469 - val_loss: 0.0259 - val_acc: 0.9997 - val_dice_coef: 0.9502
#
# Epoch 00066: val_loss improved from 0.02615 to 0.02591, saving model to ../res/u-net_aug.h5
# Epoch 67/100
# 15890/15890 [==============================] - 429s 27ms/step - loss: 0.0275 - acc: 0.9996 - dice_coef: 0.9474 - val_loss: 0.0258 - val_acc: 0.9997 - val_dice_coef: 0.9505
#
# Epoch 00067: val_loss improved from 0.02591 to 0.02577, saving model to ../res/u-net_aug.h5
# Epoch 68/100
# 15890/15890 [==============================] - 470s 30ms/step - loss: 0.0273 - acc: 0.9996 - dice_coef: 0.9477 - val_loss: 0.0263 - val_acc: 0.9997 - val_dice_coef: 0.9496
#
# Epoch 00068: val_loss did not improve from 0.02577
# Epoch 69/100
# 15890/15890 [==============================] - 429s 27ms/step - loss: 0.0272 - acc: 0.9996 - dice_coef: 0.9480 - val_loss: 0.0254 - val_acc: 0.9997 - val_dice_coef: 0.9512
#
# Epoch 00069: val_loss improved from 0.02577 to 0.02539, saving model to ../res/u-net_aug.h5
# Epoch 70/100
# 15890/15890 [==============================] - 426s 27ms/step - loss: 0.0271 - acc: 0.9996 - dice_coef: 0.9481 - val_loss: 0.0254 - val_acc: 0.9997 - val_dice_coef: 0.9513
#
# Epoch 00070: val_loss improved from 0.02539 to 0.02536, saving model to ../res/u-net_aug.h5
# Epoch 71/100
# 15890/15890 [==============================] - 429s 27ms/step - loss: 0.0269 - acc: 0.9996 - dice_coef: 0.9484 - val_loss: 0.0252 - val_acc: 0.9997 - val_dice_coef: 0.9515
#
# Epoch 00071: val_loss improved from 0.02536 to 0.02523, saving model to ../res/u-net_aug.h5
# Epoch 72/100
# 15890/15890 [==============================] - 427s 27ms/step - loss: 0.0270 - acc: 0.9996 - dice_coef: 0.9484 - val_loss: 0.0250 - val_acc: 0.9997 - val_dice_coef: 0.9520
#
# Epoch 00072: val_loss improved from 0.02523 to 0.02497, saving model to ../res/u-net_aug.h5
# Epoch 73/100
# 15890/15890 [==============================] - 428s 27ms/step - loss: 0.0266 - acc: 0.9996 - dice_coef: 0.9491 - val_loss: 0.0250 - val_acc: 0.9997 - val_dice_coef: 0.9521
#
# Epoch 00073: val_loss improved from 0.02497 to 0.02496, saving model to ../res/u-net_aug.h5
# Epoch 74/100
# 15890/15890 [==============================] - 428s 27ms/step - loss: 0.0266 - acc: 0.9996 - dice_coef: 0.9492 - val_loss: 0.0245 - val_acc: 0.9997 - val_dice_coef: 0.9529
#
# Epoch 00074: val_loss improved from 0.02496 to 0.02453, saving model to ../res/u-net_aug.h5
# Epoch 75/100
# 15890/15890 [==============================] - 430s 27ms/step - loss: 0.0263 - acc: 0.9996 - dice_coef: 0.9497 - val_loss: 0.0244 - val_acc: 0.9997 - val_dice_coef: 0.9530
#
# Epoch 00075: val_loss improved from 0.02453 to 0.02444, saving model to ../res/u-net_aug.h5
# Epoch 76/100
# 15890/15890 [==============================] - 428s 27ms/step - loss: 0.0263 - acc: 0.9996 - dice_coef: 0.9497 - val_loss: 0.0244 - val_acc: 0.9997 - val_dice_coef: 0.9531
#
# Epoch 00076: val_loss improved from 0.02444 to 0.02443, saving model to ../res/u-net_aug.h5
# Epoch 77/100
# 15890/15890 [==============================] - 427s 27ms/step - loss: 0.0262 - acc: 0.9996 - dice_coef: 0.9499 - val_loss: 0.0242 - val_acc: 0.9997 - val_dice_coef: 0.9535
#
# Epoch 00077: val_loss improved from 0.02443 to 0.02423, saving model to ../res/u-net_aug.h5
# Epoch 78/100
# 15890/15890 [==============================] - 431s 27ms/step - loss: 0.0259 - acc: 0.9996 - dice_coef: 0.9504 - val_loss: 0.0240 - val_acc: 0.9997 - val_dice_coef: 0.9539
#
# Epoch 00078: val_loss improved from 0.02423 to 0.02399, saving model to ../res/u-net_aug.h5
# Epoch 79/100
# 15890/15890 [==============================] - 427s 27ms/step - loss: 0.0259 - acc: 0.9996 - dice_coef: 0.9505 - val_loss: 0.0238 - val_acc: 0.9997 - val_dice_coef: 0.9543
#
# Epoch 00079: val_loss improved from 0.02399 to 0.02377, saving model to ../res/u-net_aug.h5
# Epoch 80/100
# 15890/15890 [==============================] - 430s 27ms/step - loss: 0.0258 - acc: 0.9996 - dice_coef: 0.9506 - val_loss: 0.0237 - val_acc: 0.9997 - val_dice_coef: 0.9545
#
# Epoch 00080: val_loss improved from 0.02377 to 0.02367, saving model to ../res/u-net_aug.h5
# Epoch 81/100
# 15890/15890 [==============================] - 426s 27ms/step - loss: 0.0255 - acc: 0.9997 - dice_coef: 0.9511 - val_loss: 0.0237 - val_acc: 0.9997 - val_dice_coef: 0.9544
#
# Epoch 00081: val_loss did not improve from 0.02367
# Epoch 82/100
# 15890/15890 [==============================] - 429s 27ms/step - loss: 0.0256 - acc: 0.9996 - dice_coef: 0.9509 - val_loss: 0.0236 - val_acc: 0.9997 - val_dice_coef: 0.9546
#
# Epoch 00082: val_loss improved from 0.02367 to 0.02363, saving model to ../res/u-net_aug.h5
# Epoch 83/100
# 15890/15890 [==============================] - 427s 27ms/step - loss: 0.0255 - acc: 0.9997 - dice_coef: 0.9513 - val_loss: 0.0234 - val_acc: 0.9997 - val_dice_coef: 0.9551
#
# Epoch 00083: val_loss improved from 0.02363 to 0.02335, saving model to ../res/u-net_aug.h5
# Epoch 84/100
# 15890/15890 [==============================] - 431s 27ms/step - loss: 0.0254 - acc: 0.9997 - dice_coef: 0.9514 - val_loss: 0.0234 - val_acc: 0.9997 - val_dice_coef: 0.9550
#
# Epoch 00084: val_loss did not improve from 0.02335
# Epoch 85/100
# 15890/15890 [==============================] - 428s 27ms/step - loss: 0.0252 - acc: 0.9997 - dice_coef: 0.9518 - val_loss: 0.0230 - val_acc: 0.9997 - val_dice_coef: 0.9557
#
# Epoch 00085: val_loss improved from 0.02335 to 0.02303, saving model to ../res/u-net_aug.h5
# Epoch 86/100
# 15890/15890 [==============================] - 429s 27ms/step - loss: 0.0250 - acc: 0.9997 - dice_coef: 0.9521 - val_loss: 0.0229 - val_acc: 0.9997 - val_dice_coef: 0.9559
#
# Epoch 00086: val_loss improved from 0.02303 to 0.02293, saving model to ../res/u-net_aug.h5
# Epoch 87/100
# 15890/15890 [==============================] - 427s 27ms/step - loss: 0.0250 - acc: 0.9997 - dice_coef: 0.9522 - val_loss: 0.0228 - val_acc: 0.9997 - val_dice_coef: 0.9562
#
# Epoch 00087: val_loss improved from 0.02293 to 0.02277, saving model to ../res/u-net_aug.h5
# Epoch 88/100
# 15890/15890 [==============================] - 430s 27ms/step - loss: 0.0247 - acc: 0.9997 - dice_coef: 0.9527 - val_loss: 0.0226 - val_acc: 0.9997 - val_dice_coef: 0.9566
#
# Epoch 00088: val_loss improved from 0.02277 to 0.02258, saving model to ../res/u-net_aug.h5
# Epoch 89/100
# 15890/15890 [==============================] - 427s 27ms/step - loss: 0.0247 - acc: 0.9997 - dice_coef: 0.9527 - val_loss: 0.0224 - val_acc: 0.9997 - val_dice_coef: 0.9569
#
# Epoch 00089: val_loss improved from 0.02258 to 0.02241, saving model to ../res/u-net_aug.h5
# Epoch 90/100
# 15890/15890 [==============================] - 428s 27ms/step - loss: 0.0245 - acc: 0.9997 - dice_coef: 0.9532 - val_loss: 0.0223 - val_acc: 0.9997 - val_dice_coef: 0.9572
#
# Epoch 00090: val_loss improved from 0.02241 to 0.02227, saving model to ../res/u-net_aug.h5
# Epoch 91/100
# 15890/15890 [==============================] - 429s 27ms/step - loss: 0.0245 - acc: 0.9997 - dice_coef: 0.9532 - val_loss: 0.0223 - val_acc: 0.9997 - val_dice_coef: 0.9572
#
# Epoch 00091: val_loss did not improve from 0.02227
# Epoch 92/100
# 15890/15890 [==============================] - 428s 27ms/step - loss: 0.0243 - acc: 0.9997 - dice_coef: 0.9534 - val_loss: 0.0223 - val_acc: 0.9997 - val_dice_coef: 0.9572
#
# Epoch 00092: val_loss did not improve from 0.02227
# Epoch 93/100
# 15890/15890 [==============================] - 430s 27ms/step - loss: 0.0243 - acc: 0.9997 - dice_coef: 0.9535 - val_loss: 0.0221 - val_acc: 0.9997 - val_dice_coef: 0.9576
#
# Epoch 00093: val_loss improved from 0.02227 to 0.02207, saving model to ../res/u-net_aug.h5
# Epoch 94/100
# 15890/15890 [==============================] - 426s 27ms/step - loss: 0.0242 - acc: 0.9997 - dice_coef: 0.9537 - val_loss: 0.0220 - val_acc: 0.9997 - val_dice_coef: 0.9578
#
# Epoch 00094: val_loss improved from 0.02207 to 0.02195, saving model to ../res/u-net_aug.h5
# Epoch 95/100
# 15890/15890 [==============================] - 430s 27ms/step - loss: 0.0240 - acc: 0.9997 - dice_coef: 0.9541 - val_loss: 0.0218 - val_acc: 0.9997 - val_dice_coef: 0.9581
#
# Epoch 00095: val_loss improved from 0.02195 to 0.02177, saving model to ../res/u-net_aug.h5
# Epoch 96/100
# 15890/15890 [==============================] - 431s 27ms/step - loss: 0.0240 - acc: 0.9997 - dice_coef: 0.9540 - val_loss: 0.0219 - val_acc: 0.9997 - val_dice_coef: 0.9579
#
# Epoch 00096: val_loss did not improve from 0.02177
# Epoch 97/100
# 15890/15890 [==============================] - 430s 27ms/step - loss: 0.0241 - acc: 0.9997 - dice_coef: 0.9540 - val_loss: 0.0216 - val_acc: 0.9997 - val_dice_coef: 0.9585
#
# Epoch 00097: val_loss improved from 0.02177 to 0.02158, saving model to ../res/u-net_aug.h5
# Epoch 98/100
# 15890/15890 [==============================] - 430s 27ms/step - loss: 0.0238 - acc: 0.9997 - dice_coef: 0.9544 - val_loss: 0.0218 - val_acc: 0.9997 - val_dice_coef: 0.9582
#
# Epoch 00098: val_loss did not improve from 0.02158
# Epoch 99/100
# 15890/15890 [==============================] - 431s 27ms/step - loss: 0.0237 - acc: 0.9997 - dice_coef: 0.9547 - val_loss: 0.0215 - val_acc: 0.9997 - val_dice_coef: 0.9586
#
# Epoch 00099: val_loss improved from 0.02158 to 0.02154, saving model to ../res/u-net_aug.h5
# Epoch 100/100
# 15890/15890 [==============================] - 429s 27ms/step - loss: 0.0235 - acc: 0.9997 - dice_coef: 0.9551 - val_loss: 0.0214 - val_acc: 0.9997 - val_dice_coef: 0.9589
#
# Epoch 00100: val_loss improved from 0.02154 to 0.02136, saving model to ../res/u-net_aug.h5

# %% [markdown]
# Learning curves visualization:

# %%
# simple model

plt.figure(figsize=(8, 8))
plt.title("Learning curve (simple model)")
plt.plot(results_simple.history["loss"], label="loss")
plt.plot(results_simple.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results_simple.history["val_loss"]), np.min(results_simple.history["val_loss"]), 
         marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("loss")
plt.legend();

# %%
# augmented model

plt.figure(figsize=(8, 8))
plt.title("Learning curve (augmented model)")
plt.plot(results_aug.history["loss"], label="loss")
plt.plot(results_aug.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results_aug.history["val_loss"]), np.min(results_aug.history["val_loss"]), 
         marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("loss")
plt.legend();

# %% [markdown]
# ## 5. Models performance on patches

# %% [markdown]
# Loading weights:

# %%
model_simple.load_weights('../res/plaq-u-net_simple.h5')
model_aug.load_weights('../res/plaq-u-net_aug.h5')

# %% [markdown]
# Evaluating on the PATCHES of the validation set:

# %%
# simple model

model_simple.evaluate(X_valid, y_valid, verbose=1)
# Out:
# 345/345 [==============================] - 6s 18ms/step
# [0.5368072518403979, 0.9538003790205803, 0.08283639675465183]

# %%
# augmented model:

model_aug.evaluate(X_valid, y_valid, verbose=1)
# Out:
# 345/345 [==============================] - 3s 7ms/step
# [0.540294717533001, 0.9638992855514306, 0.129508861316287]

# %% [markdown]
# Evaluation on the PATCHES of the test set:

# %%
# simple model

model_simple.evaluate(X_test, y_test, verbose=1)
# Out:
# 360/360 [==============================] - 4s 10ms/step
# [0.5312296522988214, 0.957460085550944, 0.08331368829700901]

# %%
# augmented model

model_aug.evaluate(X_test, y_test, verbose=1)
# Out:
# 360/360 [==============================] - 3s 7ms/step
# [0.521160227060318, 0.9693536546495226, 0.1375543196996053]

# %% [markdown]
# Predictions for the test set (+ thresholding):

# %%
preds_test_simple = model_simple.predict(X_test, verbose=1)
preds_test_simple_t = (preds_test_simple > 0.5).astype(np.uint8)

preds_test_aug = model_aug.predict(X_test, verbose=1)
preds_test_aug_t = (preds_test_aug > 0.5).astype(np.uint8)
# Out:
# 360/360 [==============================] - 3s 10ms/step
# 360/360 [==============================] - 4s 10ms/step

# %% [markdown]
# Visualization of the prediction:

# %%
from matplotlib.patches import Patch
import matplotlib.font_manager as font_manager

# %%
font = font_manager.FontProperties(family='Times New Roman', weight='ultralight', size='12')

# %%
ix = 90

fig, ax = plt.subplots(2, 2, figsize=(20, 10))

ax[0,0].imshow(X_test[ix, ..., 0], cmap='viridis')
ax[0,0].contour(y_test[ix].squeeze(), colors='r', levels=[0.5], linewidths=3)
ax[0,0].set_title('GT')
ax[0,0].grid(False)

ax[0,1].imshow(X_test[ix, ..., 0], cmap='viridis')
ax[0,1].contour(preds_test_simple[ix].squeeze(), colors='r', levels=[0.5], linewidths=5)
ax[0,1].set_title('Predicted (simple model)')
ax[0,1].grid(False)

ax[1,0].imshow(X_test[ix, ..., 0], cmap='viridis')
ax[1,0].contour(preds_test_aug[ix].squeeze(), colors='r', levels=[0.5], linewidths=5)
ax[1,0].set_title('Predicted (augmented model)')
ax[1,0].grid(False)

ax[1,1].imshow(X_test[ix, ..., 0].squeeze())
ax[1,1].contour(preds_test_simple[ix].squeeze(), colors='red', levels=[0.5], linewidths=3)
ax[1,1].contour(preds_test_aug[ix].squeeze(), colors='yellow', levels=[0.5], linewidths=3)
ax[1,1].set_title('Simple vs augmented segmentation')
#legend_elements = [Patch(facecolor='red', label='Groundtruth'),
#                   Patch(facecolor='yellow', label='Autosegmentation')]
#ax[1,1].legend(handles=legend_elements, loc=4, prop=font)
ax[1,1].grid(False)
